# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import datasets

# %%
dataset = datasets.load_dataset("roneneldan/TinyStories", cache_dir="datasets/")

# %%
embedding_dim = 128
embedding = torch.nn.Embedding(256, 128)
